# %% [markdown]
# ##Here i have trained my model 3 times with different different parameters , Lets see the results

# %%
import pandas as pd

# %%
ROOT = '/content/drive/MyDrive/DL-CV-NLP/Revision /MLflow data/runs.csv'

# %%
df = pd.read_csv(ROOT)
df
# Out:
#                              Run ID  Name  ... val_accuracy  val_loss
# 0  542d920b8d504c40a952fdca9ac7509b   NaN  ...       0.8870  0.311098
# 1  1c91bb49a81544b99244936cb9f320df   NaN  ...       0.9022  0.291881
# 2  04f3a01c32214ef2ae0699effe7be8bc   NaN  ...       0.8414  0.474921
#
# [3 rows x 33 columns]

# %% [markdown]
#    <img src="https://github.com/entbappy/Branching-tutorial/blob/master/ml%201.png?raw=true" width="600"
#      height="300">

# %% [markdown]
# Here see as number if epoch increases the accuracy also increasses but of the left you can see but accuracy are different becuase there i have used used different optimizer & parameter. If you the table then you will notice that Adam is giving good accuracy, cz its a fastest algorithm/ optimizer.

# %% [markdown]
#    <img src="https://github.com/entbappy/Branching-tutorial/blob/master/ml%202.png?raw=true" width="800"
#      height="400">

# %% [markdown]
# Here you can see all the comparison on this Parallel Coordinates Plot.

# %% [markdown]
#    <img src="https://github.com/entbappy/Branching-tutorial/blob/master/ml%203.png?raw=true" width="800"
#      height="400">

# %% [markdown]
#    <img src="https://github.com/entbappy/Branching-tutorial/blob/master/ml4.png?raw=true" width="1000"
#      height="500">

# %% [markdown]
#    <img src="https://github.com/entbappy/Branching-tutorial/blob/master/ml%205.png?raw=true" width="800"
#      height="400">

# %% [markdown]
# # Code link:
# [Click here](https://github.com/entbappy/Branching-tutorial/blob/master/autolog_dl.py)
